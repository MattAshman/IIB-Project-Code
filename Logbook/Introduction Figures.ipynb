# %%
import sys
sys.path.insert(0, '/Users/matthewashman/github/MasterProject2018')

# Import necessary modules. Set settings. Import data.
import math
import numpy as np
import pandas as pd
import random
import pywt
import parser
import matplotlib.pyplot as plt
from statsmodels.robust import mad
from tsfresh.feature_extraction import feature_calculators
from FeatureExtraction.feature_tools import detect_peaks, get_s1s2
from IPython.display import display, clear_output, HTML

import pdb

plt.style.use('default')

file_loc = '/Users/matthewashman/github/MasterProject2018/Data/EPdata/'
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# %matplotlib qt
file_name = file_loc + 'af1/afpatient1-0320.txt'
data, sr, num_samples = parser.parseFile(file_name)

axes = data[['CS1-2', 'CS3-4', 'CS5-6', 'CS7-8', 'CS9-10']].plot(subplots=True, color = 'k', figsize=(16,4), grid=True)
axes[0].legend(loc='upper left')
axes[1].legend(loc='upper left')
axes[2].legend(loc='upper left')
axes[3].legend(loc='upper left')
axes[4].legend(loc='upper left')
# axes[0].set_ylabel('CS1-2', fontweight='bold')
# axes[1].set_ylabel('CS3-4', fontweight='bold')
# axes[2].set_ylabel('CS5-6', fontweight='bold')
# axes[3].set_ylabel('CS7-8', fontweight='bold')
# axes[4].set_ylabel('CS9-10', fontweight='bold')
plt.xlabel('Sample')
plt.subplots_adjust(left=0.075, bottom=0.15, right=0.925, top=0.95, wspace=0.1, hspace=0.25)
plt.show()

# plt.savefig('/Users/matthewashman/Documents/IIB/Project/Final Report/Introduction/electrogram_example_cs_channels.png', format='png', dpi=100)

# %%
axes = data.plot(subplots=True, color = 'k', figsize=(16,9), grid=True)
for ax in axes:
    ax.legend(loc='upper left')
    
plt.xlabel('Sample')
plt.subplots_adjust(left=0.075, bottom=0.1, right=0.925, top=0.95, wspace=0.1, hspace=0.25)
plt.show()

# plt.savefig('/Users/matthewashman/Documents/IIB/Project/Final Report/Introduction/electrogram_example_cs_channels.png', format='png', dpi=100)

# %%
# %matplotlib qt
X = pd.read_pickle('/Users/matthewashman/github/MasterProject2018/Data/X_all_labels.pkl')
coupling_intervals = ('220','230', '240', '250', '260', '270', '280', '290', '300',
                      '310', '320', '330', '340', '350', '360', '370', '380', '390', '400')

X_avrt12 = epdata_main(file_loc, ('','12'), ('avrt'), list(reversed(coupling_intervals)))

avrt12_380 = X_avrt12[(X_avrt12['S1/S2'] == 'S2') & (X_avrt12['Coupling Interval'] == '380') & (X_avrt12['Channel'] == 'CS3-4')]['Data'].values[0]
avrt12_260 = X_avrt12[(X_avrt12['S1/S2'] == 'S2') & (X_avrt12['Coupling Interval'] == '260') & (X_avrt12['Channel'] == 'CS3-4')]['Data'].values[0]

plt.figure(figsize=(16,4))
plt.plot(avrt12_380, 'k')
plt.axis('off')
plt.show()
# plt.savefig('/Users/matthewashman/Documents/IIB/Project/Final Report/Introduction/non_fractionated_response.png', format='png', dpi=100)
plt.close()

plt.figure(figsize=(16,4))
plt.plot(avrt12_260, 'k')
plt.axis('off')
plt.show()
# plt.savefig('/Users/matthewashman/Documents/IIB/Project/Final Report/Introduction/fractionated_response.png', format='png', dpi=100)
plt.close()
# Out:
# Parsing error: coupling interval 400ms not available for patient .
# Parsing error: coupling interval 390ms not available for patient .
# Parsing error: coupling interval 380ms not available for patient .
# Parsing error: coupling interval 370ms not available for patient .
# Parsing error: coupling interval 360ms not available for patient .
# Parsing error: coupling interval 350ms not available for patient .
# Parsing error: coupling interval 340ms not available for patient .
# Parsing error: coupling interval 330ms not available for patient .
# Parsing error: coupling interval 320ms not available for patient .
# Parsing error: coupling interval 310ms not available for patient .
# Parsing error: coupling interval 300ms not available for patient .
# Parsing error: coupling interval 290ms not available for patient .
# Parsing error: coupling interval 280ms not available for patient .
# Parsing error: coupling interval 270ms not available for patient .
# Parsing error: coupling interval 260ms not available for patient .
# Parsing error: coupling interval 250ms not available for patient .
# Parsing error: coupling interval 240ms not available for patient .
# Parsing error: coupling interval 230ms not available for patient .
# Parsing error: coupling interval 220ms not available for patient .
# Parsing error: coupling interval 400ms not available for patient 12.
# Parsing error: coupling interval 310ms not available for patient 12.
# Parsing error: coupling interval 290ms not available for patient 12.
# Parsing error: coupling interval 270ms not available for patient 12.
# Parsing error: coupling interval 250ms not available for patient 12.
# Parsing error: coupling interval 240ms not available for patient 12.
# Parsing error: coupling interval 230ms not available for patient 12.
# Parsing error: coupling interval 220ms not available for patient 12.

# %%
X_avnrt19 = epdata_main(file_loc, ('','19'), ('avnrt'), list(reversed(coupling_intervals)))
avnrt19_300 = X_avnrt19[(X_avnrt19['S1/S2'] == 'S2') & (X_avnrt19['Coupling Interval'] == '300') & (X_avnrt19['Channel'] == 'CS3-4')]['Data'].values[0]

X_af11 = epdata_main(file_loc, ('','11'), ('af'), list(reversed(coupling_intervals)))
af11_320 = X_af11[(X_af11['S1/S2'] == 'S2') & (X_af11['Coupling Interval'] == '320') & (X_af11['Channel'] == 'CS3-4')]['Data'].values[0]

X_avnrt4 = epdata_main(file_loc, ('','4'), ('avnrt'), list(reversed(coupling_intervals)))
avnrt4_380 = X_avnrt4[(X_avnrt4['S1/S2'] == 'S2') & (X_avnrt4['Coupling Interval'] == '300') & (X_avnrt4['Channel'] == 'CS3-4')]['Data'].values[0]

plt.figure(figsize=(16,3))
plt.plot(avnrt19_300, 'k')
plt.axis('off')
plt.show()
plt.savefig('/Users/matthewashman/Documents/IIB/Project/Final Report/Introduction/red_response.png', format='png', dpi=100)
plt.close()

plt.figure(figsize=(16,3))
plt.plot(af11_320, 'k')
plt.axis('off')
plt.show()
plt.savefig('/Users/matthewashman/Documents/IIB/Project/Final Report/Introduction/amber_response.png', format='png', dpi=100)
plt.close()

plt.figure(figsize=(16,3))
plt.plot(avnrt4_380, 'k')
plt.axis('off')
plt.show()
plt.savefig('/Users/matthewashman/Documents/IIB/Project/Final Report/Introduction/green_response.png', format='png', dpi=100)
plt.close()
# Out:
# Parsing error: coupling interval 400ms not available for patient .
# Parsing error: coupling interval 390ms not available for patient .
# Parsing error: coupling interval 380ms not available for patient .
# Parsing error: coupling interval 370ms not available for patient .
# Parsing error: coupling interval 360ms not available for patient .
# Parsing error: coupling interval 350ms not available for patient .
# Parsing error: coupling interval 340ms not available for patient .
# Parsing error: coupling interval 330ms not available for patient .
# Parsing error: coupling interval 320ms not available for patient .
# Parsing error: coupling interval 310ms not available for patient .
# Parsing error: coupling interval 300ms not available for patient .
# Parsing error: coupling interval 290ms not available for patient .
# Parsing error: coupling interval 280ms not available for patient .
# Parsing error: coupling interval 270ms not available for patient .
# Parsing error: coupling interval 260ms not available for patient .
# Parsing error: coupling interval 250ms not available for patient .
# Parsing error: coupling interval 240ms not available for patient .
# Parsing error: coupling interval 230ms not available for patient .
# Parsing error: coupling interval 220ms not available for patient .
# Parsing error: coupling interval 260ms not available for patient 19.
# Parsing error: coupling interval 250ms not available for patient 19.
# Parsing error: coupling interval 240ms not available for patient 19.
# Parsing error: coupling interval 230ms not available for patient 19.
# Parsing error: coupling interval 220ms not available for patient 19.
# Parsing error: coupling interval 400ms not available for patient .
# Parsing error: coupling interval 390ms not available for patient .
# Parsing error: coupling interval 380ms not available for patient .
# Parsing error: coupling interval 370ms not available for patient .
# Parsing error: coupling interval 360ms not available for patient .
# Parsing error: coupling interval 350ms not available for patient .
# Parsing error: coupling interval 340ms not available for patient .
# Parsing error: coupling interval 330ms not available for patient .
# Parsing error: coupling interval 320ms not available for patient .
# Parsing error: coupling interval 310ms not available for patient .
# Parsing error: coupling interval 300ms not available for patient .
# Parsing error: coupling interval 290ms not available for patient .
# Parsing error: coupling interval 280ms not available for patient .
# Parsing error: coupling interval 270ms not available for patient .
# Parsing error: coupling interval 260ms not available for patient .
# Parsing error: coupling interval 250ms not available for patient .
# Parsing error: coupling interval 240ms not available for patient .
# Parsing error: coupling interval 230ms not available for patient .
# Parsing error: coupling interval 220ms not available for patient .
# Parsing error: coupling interval 400ms not available for patient 11.
# Parsing error: coupling interval 390ms not available for patient 11.
# Parsing error: coupling interval 380ms not available for patient 11.
# Parsing error: coupling interval 370ms not available for patient 11.
# Parsing error: coupling interval 360ms not available for patient 11.
# Parsing error: coupling interval 350ms not available for patient 11.
# Parsing error: coupling interval 330ms not available for patient 11.
# Parsing error: coupling interval 220ms not available for patient 11.
# Parsing error: coupling interval 400ms not available for patient .
# Parsing error: coupling interval 390ms not available for patient .
# Parsing error: coupling interval 380ms not available for patient .
# Parsing error: coupling interval 370ms not available for patient .
# Parsing error: coupling interval 360ms not available for patient .
# Parsing error: coupling interval 350ms not available for patient .
# Parsing error: coupling interval 340ms not available for patient .
# Parsing error: coupling interval 330ms not available for patient .
# Parsing error: coupling interval 320ms not available for patient .
# Parsing error: coupling interval 310ms not available for patient .
# Parsing error: coupling interval 300ms not available for patient .
# Parsing error: coupling interval 290ms not available for patient .
# Parsing error: coupling interval 280ms not available for patient .
# Parsing error: coupling interval 270ms not available for patient .
# Parsing error: coupling interval 260ms not available for patient .
# Parsing error: coupling interval 250ms not available for patient .
# Parsing error: coupling interval 240ms not available for patient .
# Parsing error: coupling interval 230ms not available for patient .
# Parsing error: coupling interval 220ms not available for patient .
# Parsing error: non-integer values in channels V1/CS9-10 for coupling interval 350ms.
# Parsing error: non-integer values in channels V1/CS9-10 for coupling interval 330ms.
# Parsing error: coupling interval 270ms not available for patient 4.
# Parsing error: coupling interval 260ms not available for patient 4.
# Parsing error: coupling interval 250ms not available for patient 4.
# Parsing error: coupling interval 240ms not available for patient 4.
# Parsing error: coupling interval 230ms not available for patient 4.
# Parsing error: coupling interval 220ms not available for patient 4.

# %%
def epdata_main(file_loc, patients, patient_type, coupling_intervals):
    X_list = [] # Initially store data in a list of dictionaries
    column_names = ['Type', 'Patient', 'Coupling Interval', 'S1/S2', 'Data']    # Column names of pandas dataframe
    for patient in patients:
        get_long_seg = True
        for coupling_interval in coupling_intervals:
            # Extract data from file
            # file_name = file_loc + 'TESTEXPORT' + file + '.txt'
            try:
                file_name = file_loc + patient_type + patient + '/' + patient_type + 'patient' + patient + '-0' + coupling_interval + '.txt'
                data, sr, num_samples = parser.parseFile(file_name)
            except FileNotFoundError:
                try:
                    file_name = file_loc + patient_type + patient + '/' + patient_type + 'patient0' + patient + '-0' + coupling_interval + '.txt'
                    data, sr, num_samples = parser.parseFile(file_name)
                except:
                    print('Parsing error: coupling interval ' + coupling_interval + 'ms not available for patient ' + patient + '.')
                    continue

            # Use the following channels
            try:
                cs34 = data['CS 3-4'].values
                cs56 = data['CS 5-6'].values
            except KeyError:
                try:
                    cs34 = data['CS3-4'].values
                    cs56 = data['CS5-6'].values
                except KeyError:
                    print('Parsing error: could not extract CS3-4 and CS5-6 values for coupling interval ' + coupling_interval + 'ms.')
                    continue
            try:
                s = data['CSp'].values
                cs12 = data['CSd'].values
            except KeyError:
                try:
                    s = data['CS9-10'].values
                    cs12 = data['CS1-2'].values
                except KeyError:
                    try:
                        s = data['CS 9-10'].values
                        cs12 = data['CS 1-2'].values
                    except KeyError:
                        print('Parsing error: could not extract channel values for coupling interval ' + coupling_interval + 'ms.')
                        continue

            channel_names = ('CS1-2', 'CS3-4', 'CS5-6')
            channels = (cs12, cs34, cs56)
            offsets = (15, 12, 12)
            if  all(isinstance(i, np.int64) for i in s):
                for channel, channel_name, offset in zip(channels, channel_names, offsets):
                    if all(isinstance(i, np.int64) for i in channel):
                        # Get segment
                        s1_segs, s2_seg = get_segment(channel, s, sr, int(coupling_interval), offset, False)
                        temp_dict = {}
                        temp_dict.update({'Type': patient_type, 'Patient': patient, 'Coupling Interval': coupling_interval, 'Channel': channel_name, 'S1/S2': 'S2', 'Data': s2_seg})
                        X_list.append(temp_dict)
                        for i,s1_seg in enumerate(s1_segs):
                            temp_dict = {}
                            temp_dict.update({'Type': patient_type, 'Patient': patient, 'Coupling Interval': coupling_interval, 'Channel': channel_name, 'S1/S2': 'S1', 'Data': s1_segs[i]})
                            X_list.append(temp_dict)
                            
                        if get_long_seg == True:
                            s2_seg = get_long_s2_segment(channel, s, sr, int(coupling_interval), offset)
                            temp_dict = {}
                            temp_dict.update({'Type': patient_type, 'Patient': patient, 'Coupling Interval': coupling_interval, 'Channel': channel_name, 'S1/S2': '-1', 'Data': s2_seg})
                            X_list.append(temp_dict)
                    else:
                        print('Parsing error: non-integer values in channel ' + channel_name + ' for coupling interval ' + coupling_interval + 'ms.')
                    
                get_long_seg = False
                
            else:
                print('Parsing error: non-integer values in channels V1/CS9-10 for coupling interval ' + coupling_interval + 'ms.')
                continue

    X = pd.DataFrame(X_list)
    return X

# %%
# Used to find S2 pulse using coupling_interval
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def get_segment(x, s, sr, coupling_interval=0, offset=10, plot_segment=True):
    # Get S1/S2 pulses from s
    s1s2_idxs = get_s1s2(s, sr, False)

    # Identify S2 pulse
    s1s2_intervals = np.diff(s1s2_idxs)
    s2_idx = find_nearest(s1s2_intervals, coupling_interval)
    s2_idx = s1s2_idxs[s2_idx+1]
    s1_idxs = np.asarray([i for i in s1s2_idxs if ((i>50) & (i<s2_idx))])
    # Add small offset
    s1_idxs += -5
    s2_idx += -5

    # For now just use strict segment length of 125.
    seg_length = 150
    s1_segs = []    # List of S1 segments
    s2_seg = x[s2_idx:(s2_idx+seg_length)] # S2 segment
    for s1_idx in s1_idxs:
        s1_segs.append(x[s1_idx:(s1_idx+seg_length)])


    if plot_segment:
        fig, [ax1, ax2] = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(16,4))
        ax1.plot(range(len(x)), x, range(s2_idx, s2_idx+seg_length), s2_seg, 'g')
        ax1.hold(True)
        for i, s1_seg in enumerate(s1_segs):
            ax1.plot(range(s1_idxs[i], (s1_idxs[i]+seg_length)), s1_seg, 'r')
        ax2.plot(range(len(s)), s)
        for idx in s1s2_idxs:
            ax2.axvline(idx, ymin=min(s), ymax=max(s), c='k', linestyle='--')
        plt.draw()
        plt.waitforbuttonpress()
        plt.close(fig)

    return np.array(s1_segs).astype(float), s2_seg

def get_long_s2_segment(x, s, sr, coupling_interval=0, offset=10):
    # Get S1/S2 pulses from s
    s1s2_idxs = get_s1s2(s, sr, False)

    # Identify S2 pulse
    s1s2_intervals = np.diff(s1s2_idxs)
    s2_idx = find_nearest(s1s2_intervals, coupling_interval)
    s2_idx = s1s2_idxs[s2_idx+1]
    # Add small offset
    s2_idx += - 50

    # For now just use strict segment length of 125.
    seg_length = 550
    s2_seg = x[s2_idx:(s2_idx+seg_length)] # S2 segment

    return s2_seg
